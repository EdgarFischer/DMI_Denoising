# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))
from denoising.figures.CompareMetabMaps import *

# %%
mat_paths = [
    #"MetabMapsProton/Vol5_Noisy_B0Corrected_After_Walinet.mat",
    #"MetabMapsProton/Vol5_Denoised_B0Corrected_After_Walinet.mat",
    #"MetabMapsProton/Vol6_Noisy_B0Corrected_After_Walinet.mat",
    #"MetabMapsProton/Vol6_Denoised_B0Corrected_After_Walinet.mat"
    "MetabMapsProton/Vol5_Brisbane_Noisy_B0Corrected_After_Walinet.mat",
    #"MetabMapsProton/Vol5_Brisbane_Noisy_B0Corrected_After_Walinet_tMPPCA.mat",
    "MetabMapsProton/Vol5_Brisbane_Denoised_B0Corrected_After_Walinet_xy.mat",
    #"MetabMapsProton/Vol5_Brisbane_Denoised_B0Corrected_After_Walinet.mat",
    "MetabMapsProton/Vol5_Brisbane_Denoised_B0Corrected_After_Walinet_fx.mat",
    #"MetabMapsProton/Vol5_Brisbane_Denoised_B0Corrected_After_Walinet_tMPPCA.mat",
]

col_titles = [
    #"No Denoising Vol5",
    #"Deep Vol5",
    #"Noisy Vol6",
    #"Deep Vol6",
    "Noisy Vol5 Brisbane",
    #"tMPPCA Vol5 Brisbane",
    "Deep_xy Vol5 Brisbane",
    #"Deep Vol5 Brisbane",
    "Deep_fx Vol5 Brisbane",
    #"Deep tMPPCA Vol5 Brisbane"
]

slice_z = 17

plot_lcmodel_comparison(mat_paths, col_titles, slice_z=slice_z)
