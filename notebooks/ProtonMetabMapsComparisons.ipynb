# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))
from denoising.figures.CompareMetabMaps import *

# %%
mat_paths = [
    "MetabMapsProton/3T/Maps/Archiv/Vol5_Brisbane_Noisy_B0Corrected_After_Walinet.mat",
    "MetabMapsProton/3T/Maps/Archiv/Vol5_Brisbane_Noisy_B0Corrected_After_Walinet_tMPPCA.mat",
    "MetabMapsProton/3T/Maps/Archiv/Vol5_Brisbane_Denoised_B0Corrected_After_Walinet_tMPPCA.mat",
    "MetabMapsProton/3T/Maps/Archiv/Vol5_Brisbane_Denoised_B0Corrected_After_Walinet_3DMask_tMPPCA.mat"
    ]

col_titles = [
    "Vol5 Noisy",
    "Vol5 tmppca",
    "Vol5 denoised + tmppca",
    "Vol5 denoised + tmppca 3D"
    ]

mask = np.load("/workspace/Denoising/datasets/Proton/7T/B0corrected_wo_LipidMask/Vol5_Brisbane/masks/brain_mask.npy")

Ref = np.load("/workspace/Denoising/datasets/Proton/7T/B0corrected_wo_LipidMask/Vol5_Brisbane//OriginalData/magnitude.npy")

Ref =  np.transpose(Ref, (2, 0, 1))


slice_z = 12

plot_lcmodel_comparison(mat_paths, col_titles, slice_z=slice_z, save_path="SavedGraphics/lcmodel_comparison.pdf", ref_image = Ref, ref_title = "Magnitude")
