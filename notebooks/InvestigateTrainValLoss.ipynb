# %%
import matplotlib.pyplot as plt

import sys
import os

sys.path.append(os.path.abspath("../src"))
from denoising.eval.log_utils import *
from denoising.figures.visualize_training import *

# %%
base_dir = "../trained_models/"

models = ["Sim_Lesion_double_xyf-z", "Sim_Lesion_double_xyf"]

# %%
plot_training_curves(
    run_dirs=models,
    base_dir=base_dir,
    show_train=False,
)
