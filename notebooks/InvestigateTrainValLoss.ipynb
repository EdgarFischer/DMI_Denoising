# %%
import matplotlib.pyplot as plt

import sys
import os

sys.path.append(os.path.abspath("../src"))
from denoising.eval.log_utils import *
from denoising.figures.visualize_training import *

# %%
model = "Sim_Lesion_double_xyf-z"

log_path = f"../trained_models/{model}/logs/train.log"

# %%
plot_training_curve(log_path, log_scale=True)
