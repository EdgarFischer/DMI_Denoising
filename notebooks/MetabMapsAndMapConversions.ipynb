# %%
import sys
import os

sys.path.append(os.path.abspath("../src"))
from denoising.figures.CompareMetabMaps import *
from denoising.data.MapConversions import *

#COMPARISONS = ['Lesion_Double_deep_tMPPCA_5D', 'Lesion_Double_tMPPCA_5D', 'Lesion_Double_GT']

#COMPARISONS = ['Lesion_Double_deep_tMPPCA_5D', 'Lesion_Double_tMPPCA_5D', 'Lesion_Double_GT']

COMPARISONS = ['Tumor_1_deep_tMPPCA_5D', 'Tumor_1_Part_1_deep_tMPPCA_5D_Ynet']

#COMPARISONS = ['Tumor_2_tMPPCA_5D', 'Tumor_2_deep_tMPPCA_5D','Tumor_2_noisy']

#COMPARISONS = ['P08_deep_tMPPCA_5D', 'P08_deep_tMPPCA_5D_Ynet'] 

quality_clip = False # show voxels that meet LC Model quality criteria
outlier_clip = False
clip_pct = 2.0 # entfernt oberste 2% der fehlerpixl um außreißer zu vermeiden

z= 10 #9

# %% [markdown]
# # Wasser

# %%
# plot_metab_maps(
#     metabolite='water',
#     methods=COMPARISONS,
#     quality_clip=False,
#     outlier_clip=outlier_clip,
#     z = z,
#     clip_pct=clip_pct  # entfernt oberste 2% der Fehlerpixel
# )

# %% [markdown]
# # Glc

# %%
# plot_metab_maps(
#     metabolite='Glc',
#     methods=COMPARISONS,
#     quality_clip=False,
#     outlier_clip=outlier_clip,
#     z = z,
#     clip_pct=clip_pct  # entfernt oberste 2% der Fehlerpixel
# )

# %% [markdown]
# # Glx

# %%
# plot_metab_maps(
#     metabolite='Glx',
#     methods=COMPARISONS,
#     quality_clip=quality_clip,
#     outlier_clip=outlier_clip,
#     z = z,
#     clip_pct=clip_pct # entfernt oberste 2% der Fehlerpixel
# )

# %% [markdown]
# # Lac

# %%
# plot_metab_maps(
#     metabolite='Lac',
#     methods=COMPARISONS,
#     quality_clip=quality_clip,
#     outlier_clip=outlier_clip,
#     z = z,
#     clip_pct=clip_pct  # entfernt oberste 2% der Fehlerpixel
# )

# %%
plot_metab_ratio(
    metab1="Lac",           # Numerator-Metabolit
    metab2="Glx",           # Denominator-Metabolit
    methods=COMPARISONS,  # zu vergleichende Methoden
    quality_clip=False,
    scale="manual",
    vmin_manual= 0,      # NEU: manuelles Minimum
    vmax_manual= 3,
    z = z
)

# %% [markdown]
# # Conversions

# %%
# written = convert_metabmaps(
#     data_dir="MetabMaps",
#     model_base="Test",
#     do_fwhm=False, do_snr=False, do_spectra=False,
#     delete_sources=True
# )

# %% [markdown]
# # Conversions SNR map + Spectra + FWHM

# %%
# written = convert_metabmaps(
#     data_dir="MetabMaps",
#     model_base="Test",
#     do_metabolites=False,
#     delete_sources=True
# )
