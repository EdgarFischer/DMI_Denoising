# %% [markdown]
# # Funktion definieren um Konzentration für jeden Zeitschritt zu berechnen

# %%
# subject = 'P07' # 'P08' 'Tumor_1"  einziger Parameter der verändert werden sollte

subjects = ["P03", "P04", "P05", "P06", "P07", "P08"]

crlb_threshold = 50

method_templates = [
    "{subject}_noisy",
    "{subject}_tMPPCA_5D",
    "{subject}_deep_tMPPCA_5D",
]

normalize_to_water = True

#COMPARISONS = ['No_Lesion_Deep', 'No_Lesion_LR8', 'No_Lesion_GT']

#COMPARISONS = ['Lesion_Double_deep_tMPPCA_5D', 'Lesion_double_Ynet', 'Lesion_Double_GT']

#COMPARISONS = ['Lesion_Double_deep_FullRank', 'Lesion_Double_Noisy', 'Lesion_Double_LR8', 'Lesion_Double_GT']

#COMPARISONS = ['Tumor_1_deep', 'Tumor_1_noisy', 'Tumor_1_Part_1_deep_tMPPCA_5D_Ynet']

#COMPARISONS = ['P08_noisy', 'P08_tMPPCA_5D', 'P08_deep_tMPPCA_5D', "P08_deep_tMPPCA_5D_On_All_Subjects"] 

#COMPARISONS = [f'{subject}_noisy', f'{subject}_tMPPCA_5D', f'{subject}_deep_tMPPCA_5D'] 

quality_clip = False # show voxels that meet LC Model quality criteria
outlier_clip = False

# Available methods:
# - P08_noDenoising
# - P08_LR8
# - P08_unet_JInvariant

# - P08_simulated_GT   -- that is ground truth
# - P08_simulated_noisy
# - P08_simulated_LR8
# - P08_simulated_unet_JInvariant

# %%
"""
timecourse_plot.py
-----------------------------------------------------------------
Plot-Funktion für PVE-Zeitverläufe beliebiger Metabolite & Methoden.

Features:
- Optional: voxelweise Normalisierung durch Water-Map
- Optional: CRLB/SD Threshold (Quelle immer methods[0])



- Plot: jede Methode (außer Referenz) eigenes Fenster; Referenz in jedem Fenster
- Quadratische Plotboxen
"""

from __future__ import annotations
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import nnls
from numpy.linalg import lstsq


# =============================================================================
# =======================   Hilfsfunktionen   =================================
# =============================================================================

def fit_pve_single_metabolite(
    metabo_map: np.ndarray,           # (X,Y,Z,T)
    tissue_maps: np.ndarray,          # (X,Y,Z,3)  GM, WM, CSF
    brain_mask: np.ndarray | None = None,   # (X,Y,Z) oder (X,Y,Z,T)
    *,
    method: str = "nnls"
) -> tuple[np.ndarray, np.ndarray]:
    """
    Schätzt Metaboliten-Konzentrationen in reinem WM, GM, CSF über die Zeit.
    Rückgabe:
        conc     (3,T)
        conc_std (3,T)
    Reihenfolge: [WM, GM, CSF]
    """

    if metabo_map.ndim != 4:
        raise ValueError(f"metabo_map must be (X,Y,Z,T), got {metabo_map.shape}")
    T = metabo_map.shape[-1]

    # Tissue maps
    gm, wm, csf = (tissue_maps[..., i].ravel() for i in range(3))

    # Brain mask
    if brain_mask is None:
        brain_mask = np.ones(metabo_map.shape[:-1], dtype=bool)
        brain_mask = brain_mask[..., None] * np.ones((1, 1, 1, T), dtype=bool)
    else:
        brain_mask = np.asarray(brain_mask, dtype=bool)
        if brain_mask.ndim == 3:
            brain_mask = brain_mask[..., None] * np.ones((1, 1, 1, T), dtype=bool)
        elif brain_mask.ndim != 4:
            raise ValueError(f"brain_mask must be 3D or 4D, got {brain_mask.shape}")

    # Flatten once
    A_all = np.vstack([wm, gm, csf]).T            # (nVox,3)  -> WM,GM,CSF
    Y_all = metabo_map.reshape(-1, T) 

    conc = np.empty((3, T), dtype=np.float64)
    conc_std = np.empty((3, T), dtype=np.float64)

    for t in range(T):
        bm = brain_mask[..., t].ravel()
        A = A_all[bm]
        y = Y_all[bm, t]

        valid = np.isfinite(y) & (y != 0)
        A = A[valid]
        y = y[valid]

        if y.size < 3:
            conc[:, t] = np.nan
            conc_std[:, t] = np.nan
            continue

        if method == "nnls":
            x, _ = nnls(A, y)
            res = y - A @ x
            cov = np.linalg.pinv(A.T @ A)
        else:
            x, *_ = lstsq(A, y, rcond=None)
            res = y - A @ x
            cov = np.linalg.pinv(A.T @ A)

        dof = max(len(y) - 3, 1)
        sigma2 = (res @ res) / dof

        conc[:, t] = x
        conc_std[:, t] = np.sqrt(sigma2 * np.diag(cov))

    return conc.astype(np.float32), conc_std.astype(np.float32)


def _suffix(quality_clip: bool, outlier_clip: bool) -> str:
    return "OutlierClip" if outlier_clip else ("QualityClip" if quality_clip else "Orig")


def _load_map(
    metabolite: str,
    method: str,
    suffix: str,
    data_dir: str,
    *,
    kind: str = "amp",   # "amp" or "sd"
) -> np.ndarray:
    path = os.path.join(
        data_dir, method, f"{metabolite}_{kind}_{method}_{suffix}.npy"
    )
    if not os.path.isfile(path):
        raise FileNotFoundError(f"Datei fehlt: {path}")
    return np.load(path)


# =============================================================================
# =======================   Hauptfunktion   ===================================
# =============================================================================

def plot_timecourse_metabolite(
    metabolite: str,
    methods: list[str],
    *,
    subject: str = "P08",
    quality_clip: bool = False,
    outlier_clip: bool = False,
    data_dir: str = "MetabMaps",
    tissue_dir: str = "../datasets",
    colors: tuple[str, ...] | None = None,
    normalize_to_water: bool = True,
    water_name: str = "water",
    eps: float = 1e-8,
    crlb_threshold: float | None = None,
) -> None:

    if len(methods) < 2:
        raise ValueError("Need at least 2 methods: [reference, comparison...]")

    suffix = _suffix(quality_clip, outlier_clip)

    # ---------------- Segmentation & Brain mask -----------------------------
    seg = np.load(os.path.join(tissue_dir, subject, "gm_wm_csf_segmentation.npy"))
    segmentations = np.swapaxes(seg, 0, -2).astype(np.float32)

    brain_mask = np.swapaxes(
        np.load(os.path.join(tissue_dir, subject, "mask.npy")), 0, -1
    ) > 0

    # ---------------- CRLB mask (optional) ----------------------------------
    crlb_mask_4d = None
    if crlb_threshold is not None:
        src = methods[0]
        crlb = _load_map(metabolite, src, suffix, data_dir, kind="sd").astype(np.float32)
        valid = np.isfinite(crlb) & (crlb < 900)
        ok = valid & (crlb <= crlb_threshold)

        bm4 = brain_mask[..., None] * np.ones((1, 1, 1, crlb.shape[-1]), dtype=bool)
        crlb_mask_4d = bm4 & ok

    # ---------------- AMP maps laden ----------------------------------------
    amp_maps, ok_methods = [], []
    for m in methods:
        amp = _load_map(metabolite, m, suffix, data_dir, kind="amp").astype(np.float32)

        if normalize_to_water:
            w = _load_map(water_name, m, suffix, data_dir, kind="amp").astype(np.float32)
            valid = np.isfinite(amp) & np.isfinite(w) & (np.abs(w) > eps)
            out = np.full_like(amp, np.nan, dtype=np.float32)
            out[valid] = amp[valid] / w[valid]
            amp = out

        amp_maps.append(amp)
        ok_methods.append(m)

    # ---------------- PVE fitting -------------------------------------------
    fit_mask = crlb_mask_4d if crlb_mask_4d is not None else brain_mask

    conc_all, conc_sd_all = [], []
    for amp in amp_maps:
        c, c_sd = fit_pve_single_metabolite(
            amp, segmentations, brain_mask=fit_mask
        )
        conc_all.append(c)
        conc_sd_all.append(c_sd)

    # ---------------- Plot ---------------------------------------------------
    tab_colors = plt.cm.get_cmap("tab10").colors
    if colors is None:
        colors = tuple(tab_colors)

    ref_name = ok_methods[0]
    ref_c, ref_sd = conc_all[0], conc_sd_all[0]

    plot_methods = ok_methods[1:]
    plot_conc = conc_all[1:]
    plot_sd = conc_sd_all[1:]

    T = ref_c.shape[1]
    time = np.arange(T)

    fig, axes = plt.subplots(
        2, len(plot_methods),
        figsize=(4.2 * len(plot_methods), 8.4),
        sharex=True
    )

    if len(plot_methods) == 1:
        axes = np.array(axes).reshape(2, 1)

    ref_wm, ref_gm = ref_c[0], ref_c[1]
    ref_wm_sd, ref_gm_sd = ref_sd[0], ref_sd[1]
    ref_ratio = ref_gm / (ref_wm + eps)
    ref_ratio_sd = ref_ratio * np.sqrt(
        (ref_gm_sd / (ref_gm + eps))**2 +
        (ref_wm_sd / (ref_wm + eps))**2
    )

    for j, (name, c, c_sd) in enumerate(zip(plot_methods, plot_conc, plot_sd)):
        ax_t, ax_r = axes[0, j], axes[1, j]
        ax_t.set_box_aspect(1)
        ax_r.set_box_aspect(1)

        # Referenz
        ax_t.errorbar(time, ref_wm, yerr=ref_wm_sd, color="k", fmt="o-", label=f"{ref_name} WM")
        ax_t.errorbar(time, ref_gm, yerr=ref_gm_sd, color="k", fmt="o--", label=f"{ref_name} GM")
        ax_r.errorbar(time, ref_ratio, yerr=ref_ratio_sd, color="k", fmt="o", label=ref_name)

        # Vergleich
        col = colors[j + 1]
        wm, gm = c[0], c[1]
        wm_sd, gm_sd = c_sd[0], c_sd[1]

        ax_t.errorbar(time, wm, yerr=wm_sd, color=col, fmt="o-", label=f"{name} WM")
        ax_t.errorbar(time, gm, yerr=gm_sd, color=col, fmt="o--", label=f"{name} GM")

        ratio = gm / (wm + eps)
        ratio_sd = ratio * np.sqrt(
            (gm_sd / (gm + eps))**2 +
            (wm_sd / (wm + eps))**2
        )
        ax_r.errorbar(time, ratio, yerr=ratio_sd, color=col, fmt="o", label=name)

        ax_t.set_title(f"{name} vs {ref_name}")
        ax_t.grid(True)
        ax_r.grid(True)

        if j == 0:
            ax_t.set_ylabel("Konzentration (a.u.)")
            ax_r.set_ylabel("GM / WM")
        else:
            ax_t.set_yticklabels([])
            ax_r.set_yticklabels([])

        ax_r.set_xlabel("Zeitpunkt")
        ax_t.legend(fontsize=8, loc="lower right")

    title = f"{metabolite}-Zeitverlauf ({suffix})"
    if normalize_to_water:
        title += " / normalized to water"
    if crlb_threshold is not None:
        title += f" / CRLB<= {crlb_threshold:g} (from {methods[0]})"

    fig.suptitle(title, fontsize=14)
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.show()

def _compute_subject_conc_from_templates(
    *,
    metabolite: str,
    method_templates: list[str],   # e.g. ["{subject}_noisy", "{subject}_tMPPCA_5D", ...]
    subject: str,
    quality_clip: bool,
    outlier_clip: bool,
    data_dir: str,
    tissue_dir: str,
    normalize_to_water: bool,
    water_name: str,
    eps: float,
    crlb_threshold: float | None,
) -> tuple[list[str], list[np.ndarray], list[np.ndarray]]:
    """
    Returns:
      methods_subj: list[str] of resolved method names for this subject
      conc_all:     list of (3,T) arrays, one per method
      conc_sd_all:  list of (3,T) arrays, one per method
    """
    suffix = _suffix(quality_clip, outlier_clip)

    methods_subj = [tpl.format(subject=subject) for tpl in method_templates]

    # Segmentation & brain mask
    seg = np.load(os.path.join(tissue_dir, subject, "gm_wm_csf_segmentation.npy"))
    segmentations = np.swapaxes(seg, 0, -2).astype(np.float32)

    brain_mask = np.swapaxes(
        np.load(os.path.join(tissue_dir, subject, "mask.npy")), 0, -1
    ) > 0

    # CRLB mask from reference only (methods_subj[0])
    crlb_mask_4d = None
    if crlb_threshold is not None:
        src = methods_subj[0]
        crlb = _load_map(metabolite, src, suffix, data_dir, kind="sd").astype(np.float32)
        valid = np.isfinite(crlb) & (crlb < 1000)
        ok = valid & (crlb <= crlb_threshold)

        bm4 = brain_mask[..., None] * np.ones((1, 1, 1, crlb.shape[-1]), dtype=bool)
        crlb_mask_4d = bm4 & ok

    # AMP maps (optional normalization)
    amp_maps = []
    for m in methods_subj:
        amp = _load_map(metabolite, m, suffix, data_dir, kind="amp").astype(np.float32)

        if normalize_to_water:
            w = _load_map(water_name, m, suffix, data_dir, kind="amp").astype(np.float32)
            valid = np.isfinite(amp) & np.isfinite(w) & (np.abs(w) > eps)
            out = np.full_like(amp, np.nan, dtype=np.float32)
            out[valid] = amp[valid] / w[valid]
            amp = out

        amp_maps.append(amp)

    # PVE fitting
    fit_mask = crlb_mask_4d if crlb_mask_4d is not None else brain_mask

    conc_all, conc_sd_all = [], []
    for amp in amp_maps:
        c, c_sd = fit_pve_single_metabolite(amp, segmentations, brain_mask=fit_mask)
        conc_all.append(c)
        conc_sd_all.append(c_sd)

    return methods_subj, conc_all, conc_sd_all


def plot_timecourse_metabolite_group(
    metabolite: str,
    method_templates: list[str],
    *,
    subjects: list[str],
    time_minutes: np.ndarray,
    y_label: str = "Normalized concentration (a.u.)",
    method_labels: dict[str, str] | None = None,
    show_tissue_legend: bool = False,  # keep False if you explain in caption: solid=GM, dashed=WM
    quality_clip: bool = False,
    outlier_clip: bool = False,
    data_dir: str = "MetabMaps",
    tissue_dir: str = "../datasets",
    colors: dict[str, str] | None = None,
    normalize_to_water: bool = True,
    water_name: str = "water",
    eps: float = 1e-8,
    crlb_threshold: float | None = None,
    x_label: str = "Time (min)",
    xticks: np.ndarray | None = None,
) -> None:
    """
    Group plot (Mean ± SD over subjects) for GM/WM timecourses.
    Colors encode methods, line style encodes tissue:
        solid = GM, dashed = WM

    Parameters
    ----------
    method_labels:
        Optional mapping from internal method name -> pretty label for legend.
        Example: {"noisy":"No denoising", "tMPPCA_5D":"tMPPCA", "deep_tMPPCA_5D":"Proposed"}
    show_tissue_legend:
        If False, omit GM/WM legend and describe in caption instead.
    """

    if time_minutes is None or len(time_minutes) == 0:
        raise ValueError("time_minutes must be provided and non-empty")
    if len(method_templates) < 2:
        raise ValueError("Need at least 2 methods: [reference, comparison...]")
    if len(subjects) < 1:
        raise ValueError("subjects must be non-empty")

    suffix = _suffix(quality_clip, outlier_clip)

    # ---------- Colors ----------
    default_colors = {
        "noisy": "#333333",
        "tMPPCA_5D": "#E69F00",
        "deep_tMPPCA_5D": "#009E73",
    }
    if colors is None:
        colors = default_colors

    # ---------- compute per subject ----------
    conc_stack = []
    methods_resolved_0 = None

    for subj in subjects:
        methods_subj, conc_all, _ = _compute_subject_conc_from_templates(
            metabolite=metabolite,
            method_templates=method_templates,
            subject=subj,
            quality_clip=quality_clip,
            outlier_clip=outlier_clip,
            data_dir=data_dir,
            tissue_dir=tissue_dir,
            normalize_to_water=normalize_to_water,
            water_name=water_name,
            eps=eps,
            crlb_threshold=crlb_threshold,
        )
        if methods_resolved_0 is None:
            methods_resolved_0 = methods_subj
        conc_stack.append(np.stack(conc_all, axis=0))

    conc_stack = np.stack(conc_stack, axis=0).astype(np.float32)  # (Nsubj,M,3,T)
    mean_conc = np.nanmean(conc_stack, axis=0)                    # (M,3,T)
    sd_conc = (
        np.nanstd(conc_stack, axis=0, ddof=1)
        if len(subjects) > 1
        else np.zeros_like(mean_conc)
    )

    # ---------- names ----------
    def _display_name(tpl: str, resolved: str) -> str:
        return tpl[len("{subject}_"):] if tpl.startswith("{subject}_") else resolved

    if methods_resolved_0 is None:
        raise RuntimeError("No methods resolved (unexpected).")

    names = [_display_name(t, r) for t, r in zip(method_templates, methods_resolved_0)]
    ref_name = names[0]
    comp_names = names[1:]

    # Pretty legend labels
    if method_labels is None:
        pretty = {n: n for n in names}
    else:
        pretty = {n: method_labels.get(n, n) for n in names}

    # ---------- sanity check: time axis length ----------
    T = mean_conc.shape[-1]
    if len(time_minutes) != T:
        raise ValueError(
            f"time_minutes length ({len(time_minutes)}) must match number of repeats T ({T})"
        )

    # ---------- y-limits (common across panels) ----------
    wm = mean_conc[:, 0, :]
    gm = mean_conc[:, 1, :]
    wm_sd = sd_conc[:, 0, :]
    gm_sd = sd_conc[:, 1, :]

    ymin = np.nanmin(np.stack([wm - wm_sd, gm - gm_sd], axis=0))
    ymax = np.nanmax(np.stack([wm + wm_sd, gm + gm_sd], axis=0))
    pad = 0.06 * (ymax - ymin + 1e-12)

    # ---------- plot ----------
    fig, axes = plt.subplots(
        1, len(comp_names),
        figsize=(7.6, 3.1),
        sharey=True,
        squeeze=False
    )

    lw, ms, cap = 1.8, 3.5, 2
    elw = 1.0

    for j, name in enumerate(comp_names):
        ax = axes[0, j]
        ref_col = colors.get(ref_name, "#333333")
        cmp_col = colors.get(name, "#0072B2")

        # reference (GM solid, WM dashed)
        ax.errorbar(
            time_minutes, mean_conc[0, 1], yerr=sd_conc[0, 1],
            color=ref_col, linestyle="-", marker="o",
            lw=lw, ms=ms, capsize=cap, elinewidth=elw
        )
        ax.errorbar(
            time_minutes, mean_conc[0, 0], yerr=sd_conc[0, 0],
            color=ref_col, linestyle="--", marker="o",
            lw=lw, ms=ms, capsize=cap, elinewidth=elw
        )

        # comparison
        idx = j + 1
        ax.errorbar(
            time_minutes, mean_conc[idx, 1], yerr=sd_conc[idx, 1],
            color=cmp_col, linestyle="-", marker="o",
            lw=lw, ms=ms, capsize=cap, elinewidth=elw
        )
        ax.errorbar(
            time_minutes, mean_conc[idx, 0], yerr=sd_conc[idx, 0],
            color=cmp_col, linestyle="--", marker="o",
            lw=lw, ms=ms, capsize=cap, elinewidth=elw
        )

        # cosmetics
        ax.set_xlabel(x_label)
        ax.set_ylim(ymin - pad, ymax + pad)
        ax.grid(True, alpha=0.2)

        if xticks is None:
            ax.set_xticks(time_minutes)
        else:
            ax.set_xticks(xticks)

        if j == 0:
            ax.set_ylabel(y_label)
        else:
            ax.tick_params(axis="y", labelleft=False)

    # ---------- legends ----------
    # ---------- legends ----------
    from matplotlib.lines import Line2D

    # 1) Methoden-Legende (oben links)
    method_handles = [
        Line2D([0], [0], color=colors.get(n, "k"), lw=lw, label=pretty[n])
        for n in names
    ]
    method_leg = axes[0, 0].legend(
        handles=method_handles,
        loc="upper left",
        frameon=False,
        fontsize=9
    )
    axes[0, 0].add_artist(method_leg)  # <- wichtig, sonst wird sie überschrieben

    # 2) Tissue-Legende (unten rechts)
    tissue_handles = [
        Line2D([0], [0], color="k", lw=lw, linestyle="-", label="GM (solid)"),
        Line2D([0], [0], color="k", lw=lw, linestyle="--", label="WM (dashed)"),
    ]
    axes[0, 0].legend(
        handles=tissue_handles,
        loc="lower right",
        frameon=False,
        fontsize=9
    )

    plt.tight_layout()
    plt.savefig("timecourse_group_Glx.pdf", bbox_inches="tight")
    plt.show()

# %%
# plot_timecourse_metabolite_group(
#     metabolite="water",
#     method_templates=method_templates,
#     subjects=subjects,
#     crlb_threshold=crlb_threshold,
#     normalize_to_water=normalize_to_water,
# )

time_minutes = [14, 21, 28, 35, 42, 49, 56, 63]

method_labels = {
    "noisy": "No denoising",
    "tMPPCA_5D": "tMPPCA",
    "deep_tMPPCA_5D": "Proposed",
}


plot_timecourse_metabolite_group(
    metabolite="Glc",
    method_templates=method_templates,
    subjects=subjects,
    time_minutes=time_minutes,
    y_label="Glc [a.u.]",
    method_labels=method_labels,
    crlb_threshold=crlb_threshold,
    normalize_to_water=normalize_to_water,
)


# plot_timecourse_metabolite_group(
#     metabolite="Glx",
#     method_templates=method_templates,
#     subjects=subjects,
#     time_minutes=time_minutes,
#     method_labels=method_labels,
#     y_label="Glx [a.u.]",
#     crlb_threshold=crlb_threshold,
#     normalize_to_water=normalize_to_water,
# )


# plot_timecourse_metabolite_group(
#     metabolite="Lac",
#     method_templates=method_templates,
#     subjects=subjects,
#     crlb_threshold=crlb_threshold,
#     normalize_to_water=normalize_to_water,
# )

# %% [markdown]
# # global division by water!

# %%
"""
timecourse_plot_global_water.py
-----------------------------------------------------------------
Group plot of GM/WM time courses with ROBUST GLOBAL water scaling.

Key change vs your current code:
- NO voxel-wise division by water maps.
- Instead: fit absolute concentrations (incl. water) with the SAME PVE model,
  then normalize tissue time courses by a GLOBAL water scale per subject.

Global water scale (per subject):
  scale = median_T( 0.5*(HDO_GM(T) + HDO_WM(T)) )

This removes inter-subject multiplicative scaling differences without ratio-noise.
"""

from __future__ import annotations
import os
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import nnls
from numpy.linalg import lstsq

# =============================================================================
# =======================   Hilfsfunktionen   =================================
# =============================================================================

def fit_pve_single_metabolite(
    metabo_map: np.ndarray,                # (X,Y,Z,T)
    tissue_maps: np.ndarray,               # (X,Y,Z,3) GM, WM, CSF
    brain_mask: np.ndarray | None = None,  # (X,Y,Z) or (X,Y,Z,T)
    *,
    method: str = "nnls"
) -> tuple[np.ndarray, np.ndarray]:
    """
    Estimate pure-tissue time courses for one metabolite.
    Returns:
      conc     (3,T)  order [WM, GM, CSF]
      conc_std (3,T)
    """
    if metabo_map.ndim != 4:
        raise ValueError(f"metabo_map must be (X,Y,Z,T), got {metabo_map.shape}")
    T = metabo_map.shape[-1]

    gm, wm, csf = (tissue_maps[..., i].ravel() for i in range(3))

    if brain_mask is None:
        brain_mask = np.ones(metabo_map.shape[:-1], dtype=bool)
        brain_mask = brain_mask[..., None] * np.ones((1, 1, 1, T), dtype=bool)
    else:
        brain_mask = np.asarray(brain_mask, dtype=bool)
        if brain_mask.ndim == 3:
            brain_mask = brain_mask[..., None] * np.ones((1, 1, 1, T), dtype=bool)
        elif brain_mask.ndim != 4:
            raise ValueError(f"brain_mask must be 3D or 4D, got {brain_mask.shape}")

    A_all = np.vstack([wm, gm, csf]).T     # (nVox,3) -> WM,GM,CSF
    Y_all = metabo_map.reshape(-1, T)

    conc = np.empty((3, T), dtype=np.float64)
    conc_std = np.empty((3, T), dtype=np.float64)

    for t in range(T):
        bm = brain_mask[..., t].ravel()
        A = A_all[bm]
        y = Y_all[bm, t]

        valid = np.isfinite(y) & (y != 0)
        A = A[valid]
        y = y[valid]

        if y.size < 3:
            conc[:, t] = np.nan
            conc_std[:, t] = np.nan
            continue

        if method == "nnls":
            x, _ = nnls(A, y)
            res = y - A @ x
            cov = np.linalg.pinv(A.T @ A)
        else:
            x, *_ = lstsq(A, y, rcond=None)
            res = y - A @ x
            cov = np.linalg.pinv(A.T @ A)

        dof = max(len(y) - 3, 1)
        sigma2 = (res @ res) / dof

        conc[:, t] = x
        conc_std[:, t] = np.sqrt(sigma2 * np.diag(cov))

    return conc.astype(np.float32), conc_std.astype(np.float32)


def _suffix(quality_clip: bool, outlier_clip: bool) -> str:
    return "OutlierClip" if outlier_clip else ("QualityClip" if quality_clip else "Orig")


def _load_map(
    metabolite: str,
    method: str,
    suffix: str,
    data_dir: str,
    *,
    kind: str = "amp",   # "amp" or "sd"
) -> np.ndarray:
    path = os.path.join(data_dir, method, f"{metabolite}_{kind}_{method}_{suffix}.npy")
    if not os.path.isfile(path):
        raise FileNotFoundError(f"File missing: {path}")
    return np.load(path)


# =============================================================================
# =============   Per-subject PVE (ABSOLUTE + GLOBAL WATER SCALE)   ===========
# =============================================================================

def _compute_subject_conc_abs_and_global_scale(
    *,
    metabolite: str,
    water_name: str,
    method_templates: list[str],    # e.g. ["{subject}_noisy", "{subject}_tMPPCA_5D", ...]
    subject: str,
    quality_clip: bool,
    outlier_clip: bool,
    data_dir: str,
    tissue_dir: str,
    crlb_threshold: float | None,
    scale_mode: str = "median_over_time",  # "median_over_time" or "per_timepoint"
    eps: float = 1e-8,
) -> tuple[list[str], list[np.ndarray], list[np.ndarray], list[np.ndarray]]:
    """
    Returns:
      method_names: resolved names for this subject (M)
      conc_m:       list of (3,T) for metabolite (absolute)
      conc_m_sd:    list of (3,T)
      scale:        list of scale arrays:
                     - if scale_mode="median_over_time": each scale is scalar (float32)
                     - if scale_mode="per_timepoint":   each scale is (T,) (float32)
    """
    suffix = _suffix(quality_clip, outlier_clip)
    methods_subj = [tpl.format(subject=subject) for tpl in method_templates]

    # Segmentation & brain mask
    seg = np.load(os.path.join(tissue_dir, subject, "gm_wm_csf_segmentation.npy"))
    segmentations = np.swapaxes(seg, 0, -2).astype(np.float32)

    brain_mask = np.swapaxes(np.load(os.path.join(tissue_dir, subject, "mask.npy")), 0, -1) > 0

    # Optional CRLB mask from REFERENCE only (methods_subj[0])
    crlb_mask_4d = None
    if crlb_threshold is not None:
        src = methods_subj[0]
        crlb = _load_map(metabolite, src, suffix, data_dir, kind="sd").astype(np.float32)
        valid = np.isfinite(crlb) & (crlb < 1000)
        ok = valid & (crlb <= crlb_threshold)
        bm4 = brain_mask[..., None] * np.ones((1, 1, 1, crlb.shape[-1]), dtype=bool)
        crlb_mask_4d = bm4 & ok

    fit_mask = crlb_mask_4d if crlb_mask_4d is not None else brain_mask

    conc_m, conc_m_sd = [], []
    scales = []

    for m in methods_subj:
        # ---- load ABSOLUTE metabolite + water maps (no division!) ----
        amp_m = _load_map(metabolite, m, suffix, data_dir, kind="amp").astype(np.float32)
        amp_w = _load_map(water_name,  m, suffix, data_dir, kind="amp").astype(np.float32)

        # ---- PVE fits (absolute) ----
        c_m, c_m_sd = fit_pve_single_metabolite(amp_m, segmentations, brain_mask=fit_mask)
        c_w, _      = fit_pve_single_metabolite(amp_w, segmentations, brain_mask=fit_mask)

        # Water tissue timecourses (order [WM, GM, CSF])
        w_wm = c_w[0]
        w_gm = c_w[1]

        # Global water scale: average GM/WM (as you requested)
        w_gmwm = 0.5 * (w_gm + w_wm)

        if scale_mode == "per_timepoint":
            scale = w_gmwm.astype(np.float32)              # (T,)
        elif scale_mode == "median_over_time":
            scale = np.nanmedian(w_gmwm).astype(np.float32)  # scalar
        else:
            raise ValueError("scale_mode must be 'median_over_time' or 'per_timepoint'")

        # Guard against divide-by-zero
        if np.isscalar(scale):
            if not np.isfinite(scale) or abs(scale) < eps:
                scale = np.float32(np.nan)
        else:
            scale = np.where(np.isfinite(scale) & (np.abs(scale) > eps), scale, np.nan).astype(np.float32)

        conc_m.append(c_m)
        conc_m_sd.append(c_m_sd)
        scales.append(scale)

    return methods_subj, conc_m, conc_m_sd, scales


# =============================================================================
# =======================   Group plot function   =============================
# =============================================================================

def plot_timecourse_metabolite_group_global_water(
    metabolite: str,
    method_templates: list[str],
    *,
    subjects: list[str],
    time_minutes: np.ndarray,
    y_label: str = "Concentration / global HDO (a.u.)",
    method_labels: dict[str, str] | None = None,
    quality_clip: bool = False,
    outlier_clip: bool = False,
    data_dir: str = "MetabMaps",
    tissue_dir: str = "../datasets",
    colors: dict[str, str] | None = None,
    water_name: str = "water",
    crlb_threshold: float | None = None,
    scale_mode: str = "median_over_time",   # "median_over_time" (recommended) or "per_timepoint"
    x_label: str = "Time (min)",
    xticks: np.ndarray | None = None,
    eps: float = 1e-8,
) -> None:
    """
    Group plot (Mean ± SD over subjects) for GM/WM timecourses.
    Colors encode methods, line style encodes tissue:
        solid = GM, dashed = WM

    GLOBAL water scaling:
      - Fit absolute concentrations for metabolite and water via PVE.
      - Normalize tissue time courses by a global subject-level water scale:
          scale = median_T(0.5*(HDO_GM(T)+HDO_WM(T)))  [default]
    """

    if len(method_templates) < 2:
        raise ValueError("Need at least 2 methods: [reference, comparison...]")
    if len(subjects) < 1:
        raise ValueError("subjects must be non-empty")
    if time_minutes is None or len(time_minutes) == 0:
        raise ValueError("time_minutes must be provided and non-empty")

    # Colors (paper-like defaults)
    default_colors = {
        "noisy": "#333333",
        "tMPPCA_5D": "#E69F00",
        "deep_tMPPCA_5D": "#009E73",
    }
    if colors is None:
        colors = default_colors

    # ---------- compute per subject ----------
    # We'll stack normalized tissue curves: (Nsubj, M, 3, T)
    conc_stack = []
    methods_resolved_0 = None

    for subj in subjects:
        methods_subj, conc_m, conc_m_sd, scales = _compute_subject_conc_abs_and_global_scale(
            metabolite=metabolite,
            water_name=water_name,
            method_templates=method_templates,
            subject=subj,
            quality_clip=quality_clip,
            outlier_clip=outlier_clip,
            data_dir=data_dir,
            tissue_dir=tissue_dir,
            crlb_threshold=crlb_threshold,
            scale_mode=scale_mode,
            eps=eps,
        )

        if methods_resolved_0 is None:
            methods_resolved_0 = methods_subj

        # Normalize each method's tissue timecourses by its own global water scale
        conc_norm = []
        for c, s in zip(conc_m, scales):
            if np.isscalar(s):
                cn = c / (s + eps)
            else:
                # s is (T,) -> broadcast to (3,T)
                cn = c / (s[None, :] + eps)
            conc_norm.append(cn.astype(np.float32))

        conc_stack.append(np.stack(conc_norm, axis=0))

    conc_stack = np.stack(conc_stack, axis=0).astype(np.float32)  # (Nsubj,M,3,T)
    mean_conc = np.nanmean(conc_stack, axis=0)                    # (M,3,T)
    sd_conc = (np.nanstd(conc_stack, axis=0, ddof=1) if len(subjects) > 1 else np.zeros_like(mean_conc))

    # ---------- names ----------
    def _display_name(tpl: str, resolved: str) -> str:
        return tpl[len("{subject}_"):] if tpl.startswith("{subject}_") else resolved

    if methods_resolved_0 is None:
        raise RuntimeError("No methods resolved (unexpected).")

    names = [_display_name(t, r) for t, r in zip(method_templates, methods_resolved_0)]
    ref_name = names[0]
    comp_names = names[1:]

    # Pretty legend labels
    if method_labels is None:
        pretty = {n: n for n in names}
    else:
        pretty = {n: method_labels.get(n, n) for n in names}

    # ---------- sanity check: time axis length ----------
    T = mean_conc.shape[-1]
    if len(time_minutes) != T:
        raise ValueError(f"time_minutes length ({len(time_minutes)}) must match repeats T ({T})")

    # ---------- y-limits (common across panels) ----------
    wm = mean_conc[:, 0, :]
    gm = mean_conc[:, 1, :]
    wm_sd = sd_conc[:, 0, :]
    gm_sd = sd_conc[:, 1, :]

    ymin = np.nanmin(np.stack([wm - wm_sd, gm - gm_sd], axis=0))
    ymax = np.nanmax(np.stack([wm + wm_sd, gm + gm_sd], axis=0))
    pad = 0.06 * (ymax - ymin + 1e-12)

    # ---------- plot ----------
    fig, axes = plt.subplots(
        1, len(comp_names),
        figsize=(9.0, 3.7),
        sharey=True,
        squeeze=False
    )

    lw, ms, cap = 1.8, 3.5, 2
    elw = 1.0

    for j, name in enumerate(comp_names):
        ax = axes[0, j]
        ref_col = colors.get(ref_name, "#333333")
        cmp_col = colors.get(name, "#0072B2")

        # reference (GM solid, WM dashed)
        ax.errorbar(time_minutes, mean_conc[0, 1], yerr=sd_conc[0, 1],
                    color=ref_col, linestyle="-", marker="o",
                    lw=lw, ms=ms, capsize=cap, elinewidth=elw)
        ax.errorbar(time_minutes, mean_conc[0, 0], yerr=sd_conc[0, 0],
                    color=ref_col, linestyle="--", marker="o",
                    lw=lw, ms=ms, capsize=cap, elinewidth=elw)

        # comparison
        idx = j + 1
        ax.errorbar(time_minutes, mean_conc[idx, 1], yerr=sd_conc[idx, 1],
                    color=cmp_col, linestyle="-", marker="o",
                    lw=lw, ms=ms, capsize=cap, elinewidth=elw)
        ax.errorbar(time_minutes, mean_conc[idx, 0], yerr=sd_conc[idx, 0],
                    color=cmp_col, linestyle="--", marker="o",
                    lw=lw, ms=ms, capsize=cap, elinewidth=elw)

        ax.set_xlabel(x_label)
        ax.set_ylim(ymin - pad, ymax + pad)
        ax.grid(True, alpha=0.2)

        ax.set_xticks(time_minutes if xticks is None else xticks)

        if j == 0:
            ax.set_ylabel(y_label)
        else:
            ax.tick_params(axis="y", labelleft=False)

    # ---------- legends (methods + tissue styles) ----------
    from matplotlib.lines import Line2D

    method_handles = [
        Line2D([0], [0], color=colors.get(n, "k"), lw=lw, label=pretty[n])
        for n in names
    ]
    method_leg = axes[0, 0].legend(handles=method_handles, loc="upper left", frameon=False, fontsize=9)
    axes[0, 0].add_artist(method_leg)

    tissue_handles = [
        Line2D([0], [0], color="k", lw=lw, linestyle="-",  label="GM (solid)"),
        Line2D([0], [0], color="k", lw=lw, linestyle="--", label="WM (dashed)"),
    ]
    axes[0, 0].legend(handles=tissue_handles, loc="lower right", frameon=False, fontsize=9)

    plt.tight_layout()
    plt.savefig(f"timecourse_group_{metabolite}_globalHDO.pdf", bbox_inches="tight")
    plt.show()


# =============================================================================
# =======================   Example usage (edit)   ============================
# =============================================================================
if __name__ == "__main__":
    # Example:
    # subjects = ["P01","P02","P03","P04","P05","P06"]
    # time_minutes = np.array([14,21,28,35,42,49,56,63])
    # method_templates = ["{subject}_noisy", "{subject}_tMPPCA_5D", "{subject}_deep_tMPPCA_5D"]
    # labels = {"noisy":"No denoising", "tMPPCA_5D":"tMPPCA", "deep_tMPPCA_5D":"Proposed"}
    #
    # plot_timecourse_metabolite_group_global_water(
    #     metabolite="Glx",
    #     method_templates=method_templates,
    #     subjects=subjects,
    #     time_minutes=time_minutes,
    #     method_labels=labels,
    #     scale_mode="median_over_time",   # recommended
    #     crlb_threshold=None,
    # )
    pass

# %%
plot_timecourse_metabolite_group_global_water(
    metabolite="Glc",
    method_templates=method_templates,
    subjects=subjects,
    time_minutes=time_minutes,
    y_label="Glc / HDO",
    method_labels=method_labels,
    crlb_threshold=crlb_threshold
)

# plot_timecourse_metabolite_group_global_water(
#     metabolite="Glx",
#     method_templates=method_templates,
#     subjects=subjects,
#     time_minutes=time_minutes,
#     y_label="Glx / HDO",
#     method_labels=method_labels,
#     crlb_threshold=crlb_threshold
# )
